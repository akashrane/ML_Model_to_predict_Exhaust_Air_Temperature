# %% [markdown]
# <a href="https://colab.research.google.com/github/akashrane/ML_Model_to_predict_Exhaust_Air_Temperature/blob/main/ML_Model_to_predict_Exhaust_Air_Temperature_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

# %%
data = pd.read_excel("/content/trainingDataANN.xlsx")

# %%
x_data = data[['hot air temperature', 'wet bulb temperature', 'expected moisture']]
y_data = data['exhaust air temperature']

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# %%
# from keras.layers import Dense, Dropout
# from keras.optimizers import Adam, RMSprop, Adagrad
# from keras.callbacks import EarlyStopping

# # Define the model
# model = Sequential()
# model.add(Dense(64, activation='relu', input_shape=(3,)))
# model.add(Dropout(0.2))
# model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(1, activation='linear'))

# # Compile the model
# optimizer = Adam(lr=0.001)
# model.compile(optimizer=optimizer, loss='mean_squared_error')

# # Define early stopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# # Train the model
# model.fit(x_train, y_train, epochs=100, validation_data=(x_val, y_val), callbacks=[early_stopping])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-7639af32007f> in <module>
#       4
#       5 # Define the model
# ----> 6 model = Sequential()
#       7 model.add(Dense(64, activation='relu', input_shape=(3,)))
#       8 model.add(Dropout(0.2))
#
# NameError: name 'Sequential' is not defined

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(10, input_shape=(3,), activation='relu'))
model.add(keras.layers.Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(x_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 106/106 [==============================] - 1s 2ms/step - loss: 2270.8459
# Epoch 2/500
# 106/106 [==============================] - 0s 2ms/step - loss: 76.4917
# Epoch 3/500
# 106/106 [==============================] - 0s 2ms/step - loss: 42.8005
# Epoch 4/500
# 106/106 [==============================] - 0s 2ms/step - loss: 39.2890
# Epoch 5/500
# 106/106 [==============================] - 0s 2ms/step - loss: 37.9885
# Epoch 6/500
# 106/106 [==============================] - 0s 2ms/step - loss: 36.8093
# Epoch 7/500
# 106/106 [==============================] - 0s 2ms/step - loss: 35.5601
# Epoch 8/500
# 106/106 [==============================] - 0s 2ms/step - loss: 34.2898
# Epoch 9/500
# 106/106 [==============================] - 0s 2ms/step - loss: 32.9500
# Epoch 10/500
# 106/106 [==============================] - 0s 2ms/step - loss: 31.5840
# Epoch 11/500
# 106/106 [==============================] - 0s 2ms/step - loss: 30.1880
# Epoch 12/500
# ...

# %%
test_loss = model.evaluate(x_test, y_test, verbose=2)
print('Test loss:', test_loss)
# Out:
# 27/27 - 0s - loss: 0.1339 - 176ms/epoch - 7ms/step
# Test loss: 0.1339101493358612

# %%
column1 = float(input("Enter the value for hot air temperature : "))
column2 = float(input("Enter the value for wet bulb temperature: "))
column3 = float(input("Enter the value for expected moisture: "))

input_data = np.array([[column1, column2, column3]])

predictions = model.predict(input_data)

print("Predicted output: ", predictions[0][0])
# Out:
# Enter the value for hot air temperature : 140
# Enter the value for wet bulb temperature: 50
# Enter the value for expected moisture: 11
# 1/1 [==============================] - 0s 25ms/step
# Predicted output:  61.94174
